# %%
### Домашнее задание к лекции "Функции"
Вам нужно помочь секретарю автоматизировать работу. 
Для этого нужно написать программу, которая будет на основе хранимых данных исполнять пользовательские команды.

# %%
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

# %%
### Задание 1
def _p(documents):   #Пункт 1. Пользователь по команде "p" может узнать владельца документа по его номеру
    doc_num = input("Введите номер документа ")
    for doc in documents:
        if doc_num == doc['number']:
            print('Владелец документа ', doc['name'])
            return()
    else:
        print('Документа нет в базе')
            
            
def _s(directors):    #Пункт 2. Пользователь по команде "s" может по номеру документа узнать на какой полке он хранитсяp
        doc_num = input("Введите номер документа ")
        directory = 0
        for diret, nums in directors.items():
            if doc_num in nums:
                directory = diret
                break
            else:
                directory = 'Документа нет в базе'
        print('Документ хранится на полке ',directory)
        
def _l(documents):  #Пункт 3. Пользователь по команде "l" может увидеть полную информацию по всем документам
    for info in documents:
        for key, val in directories.items():
            for Val in val:
                if info['number'] == Val:
                    print('№:', info['number'] , 'тип:' , info['type'] , 'владелец:' , info['name'] , 'полка хранения:' , key)
                    
def _ads(directories):   #Пункт 4. Пользователь по команде "ads" может добавить новую полку
    doc_num = input("Введите номер полки: ")
    for abasl in directories.items():
        if doc_num in abasl[0]:
            print('Такая полка уже существует. Текущий перечень полок: ', list(directories.keys()))
            break
    else:
        directories[doc_num] = []
        print('Полка добавлена. Текущий перечень полок:', list(directories.keys()))
        
def _ds(documents, directories):
    doc_num = input("Введите номер полки:")
    if doc_num not in directories.keys():
        print('Такой полки не существует. Текущий перечень полок:', list(directories.keys()))
    elif len (directories[doc_num]) > 0:
        print ('На полке есть документы, удалите их перед удалением полки. Текущий перечень полок: ', list(directories.keys()))
    else:
        del(directories[doc_num])
        print('Полка удалена. Текущий перечень полок:', list(directories.keys()))

            
def main():
    while True:
        user = input('Введите команду ')
        if user == 'p':
            _p(documents)
        elif user == 's':
            _s(directories)
        elif user == 'l':
            _l(documents)
        elif user == 'ads':
            _ads(directories)
        elif user == 'ds':
            _ds(documents, directories)
        elif user == 'q':
            print('Программа закончена')
            break
main()
# Out:
# Введите команду p
# Введите номер документа 100
# Документа нет в базе
# Введите команду p
# Введите номер документа 10006
# Владелец документа  Аристарх Павлов
# Введите команду s
# Введите номер документа 34
# Документ хранится на полке  Документа нет в базе
# Введите команду s
# Введите номер документа 10006
# Документ хранится на полке  2
# Введите команду l
# №: 2207 876234 тип: passport владелец: Василий Гупкин полка хранения: 1
# №: 11-2 тип: invoice владелец: Геннадий Покемонов полка хранения: 1
# №: 10006 тип: insurance владелец: Аристарх Павлов полка хранения: 2
# Введите команду ads
# Введите номер полки: 1
# Такая полка уже существует. Текущий перечень полок:  ['1', '2', '3']
# Введите команду ads
# Введите номер полки: 5
# Полка добавлена. Текущий перечень полок: ['1', '2', '3', '5']
# Введите команду ds
# Введите номер полки:1
# На полке есть документы, удалите их перед удалением полки. Текущий перечень полок:  ['1', '2', '3', '5']
# Введите команду ds
# ...
